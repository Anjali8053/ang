# %%
import pandas as pd 
import numpy as nm 
info = [ 1.0,2.0,3.0,]
In = ["apple","banana","grapes"]
S1 = pd.Series(data=info,index=In)
print(In[2],info[2])
# Out:
# grapes 3.0

# %%
S1.describe()
# Out:
# count    3.0
# mean     2.0
# std      1.0
# min      1.0
# 25%      1.5
# 50%      2.0
# 75%      2.5
# max      3.0
# dtype: float64

# %%
S1.shape
# Out:
# (3,)

# %%
S1.ndim
# Out:
# 1

# %%
S1.dtype
# Out:
# dtype('float64')

# %%
list=[1,2,3,4]
z=list[:3]
print(z)
# Out:
# [1, 2, 3]

# %% [markdown]
# # how do you import the pandas libraries?

# %% [markdown]
# ##how do you import the pandas libraries?

# %%
import pandas as pd 

import numpy as nm 
info = [ 1.0,2.0,3.0,]
In = ["apple","banana","grapes"]
S1 = pd.Series(data=info,index=In)
print()

# %%
import pandas as pd
data = {'name':['parveen','rajesh','sumadar'], 'age':[25,48,20], 'city':['delhi','newnork','goa']}
df= pd.DataFrame(data)
print(df)
# Out:
#       name  age     city
# 0  parveen   25    delhi
# 1   rajesh   48  newnork
# 2  sumadar   20      goa

# %%
df['name']
df
# Out:
#       name  age     city
# 0  parveen   25    delhi
# 1   rajesh   48  newnork
# 2  sumadar   20      goa

# %%
df=pd.read_csv('cvs.csv')
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
import pandas as pd
data = {'name':['parveen','rajesh','sumadar'], 'age':[25,48,20], 'city':['delhi','newnork','goa']}
df= pd.DataFrame(data)
print(df)
# Out:
#       name  age     city
# 0  parveen   25    delhi
# 1   rajesh   48  newnork
# 2  sumadar   20      goa

# %%
df=pd.read_csv('a.csv.csv')
df
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2023                  all                     All Industries
# 20120  2023                  all                     All Industries
# 20121  2023                  all                     All Industries
# 20122  2023                  all                     All Industries
# 20123  2023                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
df.head()
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable  value               unit
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
# 4                                     Total income   8866  DOLLARS(millions)

# %%
df.tail()
# Out:
#        year industry_code_ANZSIC industry_name_ANZSIC   rme_size_grp  \
# 20119  2023                  all       All Industries  j_Grand_Total
# 20120  2023                  all       All Industries  j_Grand_Total
# 20121  2023                  all       All Industries  j_Grand_Total
# 20122  2023                  all       All Industries  j_Grand_Total
# 20123  2023                  all       All Industries  j_Grand_Total
#
#                           variable    value               unit
# 20119                 Total income   930995  DOLLARS(millions)
# 20120            Total expenditure   832964  DOLLARS(millions)
# 20121  Operating profit before tax   103616  DOLLARS(millions)
# 20122                 Total assets  2831894  DOLLARS(millions)
# 20123        Fixed tangible assets   681890  DOLLARS(millions)

# %%
df.describe()
# Out:
#               year
# count  20124.00000
# mean    2017.00000
# std        3.74175
# min     2011.00000
# 25%     2014.00000
# 50%     2017.00000
# 75%     2020.00000
# max     2023.00000

# %%
df.variable
# Out:
# 0                                          Activity unit
# 1                                 Rolling mean employees
# 2                                Salaries and wages paid
# 3        Sales, government funding, grants and subsidies
# 4                                           Total income
#                               ...
# 20119                                       Total income
# 20120                                  Total expenditure
# 20121                        Operating profit before tax
# 20122                                       Total assets
# 20123                              Fixed tangible assets
# Name: variable, Length: 20124, dtype: object

# %%
df.value
# Out:
# 0          46134
# 1              0
# 2            279
# 3           8187
# 4           8866
#           ...
# 20119     930995
# 20120     832964
# 20121     103616
# 20122    2831894
# 20123     681890
# Name: value, Length: 20124, dtype: object

# %%
df.unit
# Out:
# 0                    COUNT
# 1                    COUNT
# 2        DOLLARS(millions)
# 3        DOLLARS(millions)
# 4        DOLLARS(millions)
#                ...
# 20119    DOLLARS(millions)
# 20120    DOLLARS(millions)
# 20121    DOLLARS(millions)
# 20122    DOLLARS(millions)
# 20123    DOLLARS(millions)
# Name: unit, Length: 20124, dtype: object

# %%
df.isnull()
# Out:
#         year  industry_code_ANZSIC  industry_name_ANZSIC  rme_size_grp  \
# 0      False                 False                 False         False
# 1      False                 False                 False         False
# 2      False                 False                 False         False
# 3      False                 False                 False         False
# 4      False                 False                 False         False
# ...      ...                   ...                   ...           ...
# 20119  False                 False                 False         False
# 20120  False                 False                 False         False
# 20121  False                 False                 False         False
# 20122  False                 False                 False         False
# 20123  False                 False                 False         False
#
#        variable  value   unit
# 0         False  False  False
# 1         False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# year                    0
# industry_code_ANZSIC    0
# industry_name_ANZSIC    0
# rme_size_grp            0
# variable                0
# value                   0
# unit                    0
# dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=20124, step=1)

# %%
df.dropna()
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2023                  all                     All Industries
# 20120  2023                  all                     All Industries
# 20121  2023                  all                     All Industries
# 20122  2023                  all                     All Industries
# 20123  2023                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
df.isnull().sum()
# Out:
# year                    0
# industry_code_ANZSIC    0
# industry_name_ANZSIC    0
# rme_size_grp            0
# variable                0
# value                   0
# unit                    0
# dtype: int64

# %%
i = 1
while i < 6:
  print(i)
  i = i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while i < 100:
    print(i)
    i = i-5
# Out:
# 1
# 6
# 11
# 16
# 21
# 26
# 31
# 36
# 41
# 46
# 51
# 56
# 61
# 66
# 71
# 76
# 81
# 86
# 91
# 96

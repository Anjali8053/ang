# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\ctc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# # line graph

# %%
y=np.random.randint(0,10,10)
x=np.arange(0,10)

# %%
plt.plot(x,y,label='line',color='yellow',linestyle='dashed',linewidth='3',gapcolor='black')
plt.show()

# %%
dog=('water','drink','chips','amgic','sting','juice')
cat=(400,700,1000,300,5000,600)

# %%
plt.bar(cat,dog)
plt.show()

# %%
marks=(700,200,300,500)
students=('ritesh','yash','parveen','samunder')

# %%
plt.bar(marks,students,color='yellow',edgecolor='blue')
plt.title('students marksheet')
plt.ylabel('student name')
plt.xlabel('marks')
plt.show()

# %%
data={'products':['products a','products b','product c'],'revenue':[5000,7000,9000]}
pd.DataFrame(data)
# Out:
#      products  revenue
# 0  products a     5000
# 1  products b     7000
# 2   product c     9000

# %%
plt.bar(df['products']df['revenue'])
plt.title(data)
plt.xlabel('products')
plt.ylabel('revenue')
plt.show
# Out:
#   Cell In[56], line 1
#     plt.bar(df['products']df['revenue'])
#             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
